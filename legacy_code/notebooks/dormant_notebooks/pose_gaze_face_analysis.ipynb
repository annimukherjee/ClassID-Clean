# %%
import numpy as np
import pandas as pd
import scipy.stats

pd.options.mode.chained_assignment = None
from matplotlib import pyplot as plt, rcParams
# import cv2
import seaborn as sns

sns.set(style="white", context="paper")
from cycler import cycler
import os, sys
import glob
from datetime import datetime, timedelta
from itertools import combinations
import base64
from PIL import Image
from io import BytesIO as _BytesIO
import requests
import json
import pickle
from datetime import datetime
from IPython.display import display, Markdown, Latex
from sklearn.metrics import *
import collections
from copy import deepcopy
import traceback
# import plotly
# from pandas_profiling import ProfileReport

pd.options.display.max_columns = None


def printm(s): return display(Markdown(s))

# %%
SERVER_CACHE_DIR = '/mnt/ci-nas-cache/edulyzeV2/cache_compute_4/'
os.makedirs(SERVER_CACHE_DIR,exist_ok=True)

# %% [markdown]
# # Figure out how many sessions are there, and how many frames for each session

# %%
analysis_meta_cache = f'{SERVER_CACHE_DIR}/analysis_all/meta_info_all'
os.makedirs(analysis_meta_cache,exist_ok=True)

# %%
base_dir = '/mnt/ci-nas-cache/edulyzeV2/pose_face_gaze_emb/'
frame_file_data = {}
for course_idx, course_dir in enumerate(glob.glob(f"{base_dir}/*")):
    course_name = course_dir.split("/")[-1]
    course_cache_file = f"{analysis_meta_cache}/{course_name}"
    if os.path.exists(course_cache_file):
        frame_file_data[course_name] = pickle.load(open(course_cache_file,"rb"))
        continue
    frame_file_data[course_name]={}
        
    for session_idx, session_dir in enumerate(glob.glob(f"{course_dir}/*")):
        session_name = session_dir.split("/")[-1]
        frame_file_data[course_name][session_name] = {}
        frame_files = glob.glob(f"{session_dir}/*")
        frame_file_names = [xr.split("/")[-1] for xr in frame_files]
        if 'end.pb' in frame_file_names:
            frame_file_data[course_name][session_name]['is_completed']=True
        else:
            frame_file_data[course_name][session_name]['is_completed']=False            
        frame_ids = [int(xr.split(".")[0]) for xr in frame_file_names if not (xr=='end.pb')]
        frame_file_data[course_name][session_name]['frame_ids'] = sorted(frame_ids)
        frame_file_data[course_name][session_name]['dir_location'] = session_dir
        print(f"Got metadata for course: {course_idx}-{course_name}, session:{session_idx}-{session_name}")
    pickle.dump(frame_file_data[course_name],open(course_cache_file,"wb"))

# %%
len(frame_file_data['05410A']['classinsight-cmu_05410A_ghc_4301_201902181500-front']['frame_ids'])
# Out:
# 23843

# %%
# course_name, session_name, is_completed, min_frame, max_frame_number, num_frames, session_duration_mins, 
# Next step: Get how many sessions are completed, and 
session_infos = []
for course_name in frame_file_data:
    session_meta_data = {'course':course_name}
    for session_name in frame_file_data[course_name]:
        print(session_name)
        session_meta_data['session']=session_name.split("-front")[0]
        try:
            session_meta_data['start_time'] = pd.to_datetime(session_meta_data['session'].split("_")[-1], format="%Y%m%d%H%M")
        except:
            session_meta_data['start_time'] = pd.to_datetime(session_meta_data['session'].split("_")[-1], format="%Y%m%d%H%M%S")
        session_meta_data['start_hour'] = session_meta_data['start_time'].strftime('%H:%M')
        session_meta_data['classroom'] = "_".join(session_meta_data['session'].split("_")[-3:-1])
        meta_data = frame_file_data[course_name][session_name]
        session_meta_data['completed'] = meta_data['is_completed']
        # print(meta_data['frame_ids'])
        session_meta_data['num_frames'] = len(meta_data['frame_ids'])
        if len(meta_data['frame_ids']) > 0:
            session_meta_data['max_frame'] = max(meta_data['frame_ids'])
            session_meta_data['duration_in_mins'] = max(meta_data['frame_ids'])//(15*60)
        session_infos.append(session_meta_data)
        # print(course_name, session_name)
df_session_info = pd.DataFrame(session_infos)
# Out:
# classinsight-cmu_05410A_ghc_4301_201902181500-front
# classinsight-cmu_05410A_ghc_4301_201902251500-front
# classinsight-cmu_05410A_ghc_4301_201904081500-front
# classinsight-cmu_05410A_ghc_4301_201904151500-front
# classinsight-cmu_05410A_ghc_4301_201904221500-front
# classinsight-cmu_21127J_ghc_4102_201903190930-front
# classinsight-cmu_21127J_ghc_4102_201903260930-front
# classinsight-cmu_21127J_ghc_4102_201904160930-front
# classinsight-cmu_21127J_ghc_4102_201904230930-front
# classinsight-cmu_21127J_ghc_4102_201904300930-front
# classinsight-cmu_05748A_ghc_4101_201902051630-front
# classinsight-cmu_05748A_ghc_4101_201902141630-front
# classinsight-cmu_05748A_ghc_4101_201902281630-front
# classinsight-cmu_05748A_ghc_4101_201903071630-front
# classinsight-cmu_05748A_ghc_4101_201904021630-front
# classinsight-cmu_05748A_ghc_4101_201901291630-front
# classinsight-cmu_05418A_ghc_4102_201904081200-front
# classinsight-cmu_05418A_ghc_4102_201904011200-front
# classinsight-cmu_05418A_ghc_4102_201904291200-front
# classinsight-cmu_05418A_ghc_4102_201905011200-front
# classinsight-cmu_05418A_ghc_4102_201902251200-front
# classinsight-cmu_05418A_ghc_4102_201904031200-front
# classinsight-cmu_05681A_ghc_4301_201902201630-front
# classinsight-cmu_05681A_ghc_4301_201904101630-front
# classinsight-cmu_05681A_ghc_4301_201904171630-front
# classinsight-cmu_05681A_ghc_4301_201901231630-front
# classinsight-cmu_05681A_ghc_4301_201905011630-front
# classinsight-cmu_05681A_ghc_4301_201901301630-front
# classinsight-cmu_05681A_ghc_4301_201902061630-front
# classinsight-cmu_17214B_ph_a21_201902271030-front
# classinsight-cmu_17214B_ph_a21_201903061030-front
# classinsight-cmu_17214B_ph_a21_201904031030-front
# classinsight-cmu_17214B_ph_a21_201904101030-front
# classinsight-cmu_17214B_ph_a21_201904241030-front
# classinsight-cmu_17214B_ph_a21_201901301030-front
# classinsight-cmu_17214B_ph_a21_201903131030-front
# classinsight-cmu_17214B_ph_a21_201903201030-front
# classinsight-cmu_17214C_ph_225b_201904031130-front
# classinsight-cmu_17214C_ph_225b_201904101130-front
# classinsight-cmu_17214C_ph_225b_201904171130-front
# classinsight-cmu_17214C_ph_225b_201904241130-front
# classinsight-cmu_17214C_ph_225b_201905011130-front
# classinsight-cmu_17214C_ph_225b_201903201130-front
# classinsight-cmu_05410B_ghc_4211_201902111500-front
# classinsight-cmu_05410B_ghc_4211_201903181500-front
# classinsight-cmu_05410B_ghc_4211_201904081500-front
# classinsight-cmu_05410B_ghc_4211_201904151500-front
# classinsight-cmu_05410B_ghc_4211_201904221500-front
# classinsight-cmu_05410B_ghc_4211_201901281500-front
# classinsight-cmu_05410B_ghc_4211_201901301500-front
# classinsight-cmu_05410B_ghc_4211_201902041500-front

# %%
session_infos[-1]
# Out:
# {'course': '05410B',
#  'session': 'classinsight-cmu_05410B_ghc_4211_201902041500',
#  'start_time': Timestamp('2019-02-04 15:00:00'),
#  'start_hour': '15:00',
#  'classroom': 'ghc_4211',
#  'completed': False,
#  'num_frames': 562,
#  'max_frame': 3366,
#  'duration_in_mins': 3}

# %%
df_session_info
# Out:
#     course                                        session          start_time  \
# 0   05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 1   05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 2   05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 3   05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 4   05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 5   21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 6   21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 7   21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 8   21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 9   21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 10  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 11  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 12  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 13  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 14  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 15  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 16  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 17  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 18  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
# 19  21127J  classinsight-cmu_21127J_ghc_4102_201904300930 2019-04-30 09:30:00
#
#    start_hour classroom  completed  num_frames  max_frame  duration_in_mins  \
# 0       15:00  ghc_4301       True       23998      71991                79
# 1       15:00  ghc_4301       True       23998      71991                79
# 2       15:00  ghc_4301       True       23998      71991                79
# 3       15:00  ghc_4301       True       23998      71991                79
# 4       15:00  ghc_4301       True       23998      71991                79
# 5       09:30  ghc_4102       True       14999      44994                49
# 6       09:30  ghc_4102       True       14999      44994                49
# 7       09:30  ghc_4102       True       14999      44994                49
# 8       09:30  ghc_4102       True       14999      44994                49
# 9       09:30  ghc_4102       True       14999      44994                49
# 10      09:30  ghc_4102       True       14999      44994                49
# 11      09:30  ghc_4102       True       14999      44994                49
# 12      09:30  ghc_4102       True       14999      44994                49
# 13      09:30  ghc_4102       True       14999      44994                49
# 14      09:30  ghc_4102       True       14999      44994                49
# 15      09:30  ghc_4102       True       14999      44994                49
# 16      09:30  ghc_4102       True       14999      44994                49
# 17      09:30  ghc_4102       True       14999      44994                49
# 18      09:30  ghc_4102       True       14999      44994                49
# 19      09:30  ghc_4102       True       14999      44994                49
#
#     course_num  S.No Semester                   Division Dept  \
# 0         5410     8      NaN                        NaN  NaN
# 1         5410     8      NaN                        NaN  NaN
# 2         5410     8      NaN                        NaN  NaN
# 3         5410     8      NaN                        NaN  NaN
# 4         5410     8      NaN                        NaN  NaN
# 5        21127    13     Fall  Mellon College of Science  MSC
# 6        21127    31   Spring  Mellon College of Science  MSC
# 7        21127    42   Summer  Mellon College of Science  MSC
# 8        21127    13     Fall  Mellon College of Science  MSC
# 9        21127    31   Spring  Mellon College of Science  MSC
# 10       21127    42   Summer  Mellon College of Science  MSC
# 11       21127    13     Fall  Mellon College of Science  MSC
# 12       21127    31   Spring  Mellon College of Science  MSC
# 13       21127    42   Summer  Mellon College of Science  MSC
# 14       21127    13     Fall  Mellon College of Science  MSC
# 15       21127    31   Spring  Mellon College of Science  MSC
# 16       21127    42   Summer  Mellon College of Science  MSC
# 17       21127    13     Fall  Mellon College of Science  MSC
# 18       21127    31   Spring  Mellon College of Science  MSC
# 19       21127    42   Summer  Mellon College of Science  MSC
#
#                               course_name   Course Level  Hrs Per Week  \
# 0   User-Centered Research and Evaluation            NaN           NaN
# 1   User-Centered Research and Evaluation            NaN           NaN
# 2   User-Centered Research and Evaluation            NaN           NaN
# 3   User-Centered Research and Evaluation            NaN           NaN
# 4   User-Centered Research and Evaluation            NaN           NaN
# 5                    CONCEPTS OF MATHMTCS  Undergraduate         12.60
# 6                    CONCEPTS OF MATHMTCS  Undergraduate         11.17
# 7                    CONCEPTS OF MATHMTCS  Undergraduate         17.12
# 8                    CONCEPTS OF MATHMTCS  Undergraduate         12.60
# 9                    CONCEPTS OF MATHMTCS  Undergraduate         11.17
# 10                   CONCEPTS OF MATHMTCS  Undergraduate         17.12
# 11                   CONCEPTS OF MATHMTCS  Undergraduate         12.60
# 12                   CONCEPTS OF MATHMTCS  Undergraduate         11.17
# 13                   CONCEPTS OF MATHMTCS  Undergraduate         17.12
# 14                   CONCEPTS OF MATHMTCS  Undergraduate         12.60
# 15                   CONCEPTS OF MATHMTCS  Undergraduate         11.17
# 16                   CONCEPTS OF MATHMTCS  Undergraduate         17.12
# 17                   CONCEPTS OF MATHMTCS  Undergraduate         12.60
# 18                   CONCEPTS OF MATHMTCS  Undergraduate         11.17
# 19                   CONCEPTS OF MATHMTCS  Undergraduate         17.12
#
#    course_category                                        description  \
# 0           theory  This course provides an overview and introduct...
# 1           theory  This course provides an overview and introduct...
# 2           theory  This course provides an overview and introduct...
# 3           theory  This course provides an overview and introduct...
# 4           theory  This course provides an overview and introduct...
# 5           theory  This course introduces the basic concepts, ide...
# 6           theory  This course introduces the basic concepts, ide...
# 7           theory  This course introduces the basic concepts, ide...
# 8           theory  This course introduces the basic concepts, ide...
# 9           theory  This course introduces the basic concepts, ide...
# 10          theory  This course introduces the basic concepts, ide...
# 11          theory  This course introduces the basic concepts, ide...
# 12          theory  This course introduces the basic concepts, ide...
# 13          theory  This course introduces the basic concepts, ide...
# 14          theory  This course introduces the basic concepts, ide...
# 15          theory  This course introduces the basic concepts, ide...
# 16          theory  This course introduces the basic concepts, ide...
# 17          theory  This course introduces the basic concepts, ide...
# 18          theory  This course introduces the basic concepts, ide...
# 19          theory  This course introduces the basic concepts, ide...
#
#     Interest in student learning  Clearly explain course requirements  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
# 5                           4.04                                 4.27
# 6                           4.34                                 4.42
# 7                           4.76                                 4.76
# 8                           4.04                                 4.27
# 9                           4.34                                 4.42
# 10                          4.76                                 4.76
# 11                          4.04                                 4.27
# 12                          4.34                                 4.42
# 13                          4.76                                 4.76
# 14                          4.04                                 4.27
# 15                          4.34                                 4.42
# 16                          4.76                                 4.76
# 17                          4.04                                 4.27
# 18                          4.34                                 4.42
# 19                          4.76                                 4.76
#
#     Clear learning objectives & goals  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                4.25
# 6                                4.37
# 7                                4.82
# 8                                4.25
# 9                                4.37
# 10                               4.82
# 11                               4.25
# 12                               4.37
# 13                               4.82
# 14                               4.25
# 15                               4.37
# 16                               4.82
# 17                               4.25
# 18                               4.37
# 19                               4.82
#
#     Instructor provides feedback to students to improve  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                3.73
# 6                                                3.98
# 7                                                4.41
# 8                                                3.73
# 9                                                3.98
# 10                                               4.41
# 11                                               3.73
# 12                                               3.98
# 13                                               4.41
# 14                                               3.73
# 15                                               3.98
# 16                                               4.41
# 17                                               3.73
# 18                                               3.98
# 19                                               4.41
#
#     Demonstrate importance of subject matter  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                       4.05
# 6                                       4.33
# 7                                       4.79
# 8                                       4.05
# 9                                       4.33
# 10                                      4.79
# 11                                      4.05
# 12                                      4.33
# 13                                      4.79
# 14                                      4.05
# 15                                      4.33
# 16                                      4.79
# 17                                      4.05
# 18                                      4.33
# 19                                      4.79
#
#     Explains subject matter of course  Show respect for all students  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# 5                                4.16                           4.15
# 6                                4.31                           4.56
# 7                                4.79                           4.68
# 8                                4.16                           4.15
# 9                                4.31                           4.56
# 10                               4.79                           4.68
# 11                               4.16                           4.15
# 12                               4.31                           4.56
# 13                               4.79                           4.68
# 14                               4.16                           4.15
# 15                               4.31                           4.56
# 16                               4.79                           4.68
# 17                               4.16                           4.15
# 18                               4.31                           4.56
# 19                               4.79                           4.68
#
#     Overall teaching rate  Overall course rate
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# 5                    4.06                 3.92
# 6                    4.29                 4.18
# 7                    4.76                 4.62
# 8                    4.06                 3.92
# 9                    4.29                 4.18
# 10                   4.76                 4.62
# 11                   4.06                 3.92
# 12                   4.29                 4.18
# 13                   4.76                 4.62
# 14                   4.06                 3.92
# 15                   4.29                 4.18
# 16                   4.76                 4.62
# 17                   4.06                 3.92
# 18                   4.29                 4.18
# 19                   4.76                 4.62

# %%
df_session_info = df_session_info[df_session_info.completed]
df_session_info['course_num'] = df_session_info.course.apply(lambda x: int(x[:5]) if len(x)>5 else int(x[:4]))
df_session_info['course_num'].value_counts()
# Out:
# 5410     5
# 21127    5
# Name: course_num, dtype: int64

# %% [markdown]
# # Include course meta info

# %%
df_course_info = pd.read_csv('course_descriptions_1.csv')
df_course_info2 = pd.read_csv('course_descriptions_2.csv')
df_course_info = pd.concat([df_course_info,df_course_info2],ignore_index=True)
df_course_info = df_course_info[~df_course_info.course_name.isnull()]
df_course_info.info()
df_course_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 0 to 64
# Data columns (total 19 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   S.No                                                 63 non-null     int64
#  1   Semester                                             51 non-null     object
#  2   Division                                             51 non-null     object
#  3   Dept                                                 51 non-null     object
#  4   course_num                                           63 non-null     int64
#  5   course_name                                          63 non-null     object
#  6   Course Level                                         51 non-null     object
#  7   Hrs Per Week                                         51 non-null     float64
#  8   course_category                                      62 non-null     object
#  9   description                                          63 non-null     object
#  10  Interest in student learning                         51 non-null     float64
#  11  Clearly explain course requirements                  51 non-null     float64
#  12  Clear learning objectives & goals                    51 non-null     float64
#  13  Instructor provides feedback to students to improve  51 non-null     float64
#  14  Demonstrate importance of subject matter             51 non-null     float64
#  15  Explains subject matter of course                    51 non-null     float64
#  16  Show respect for all students                        51 non-null     float64
#  17  Overall teaching rate                                51 non-null     float64
#  18  Overall course rate                                  51 non-null     float64
# dtypes: float64(10), int64(2), object(7)
# memory usage: 9.8+ KB
#    S.No Semester                          Division Dept  course_num  \
# 0     1     Fall  Carnegie Institute of Technology  CHE        6705
# 1     2     Fall         Mellon College of Science  CMY        9214
# 2     3     Fall         Mellon College of Science  CMY        9403
# 3     4     Fall  Carnegie Institute of Technology  CEE       12411
# 4     5     Fall        School of Computer Science   CS       15251
#
#             course_name   Course Level  Hrs Per Week course_category  \
# 0   ADV CHE THRMODYNMCS       Graduate          8.16          theory
# 1    PHYSICAL CHEMISTRY  Undergraduate          6.50          theory
# 2             CMY ADDIC  Undergraduate          5.75          theory
# 3  PRJ MANGMT CONSTRCTN  Undergraduate          7.46         applied
# 4  GRT IDEAS THERTCL CS  Undergraduate         14.27          theory
#
#                                          description  \
# 0  Advanced application of the general thermodyna...
# 1  This is a one-semester course intended primari...
# 2  What makes us need something so much that it e...
# 3  Through planning and management, and optimizat...
# 4  This course is about how to use theoretical id...
#
#    Interest in student learning  Clearly explain course requirements  \
# 0                          4.42                                 4.63
# 1                          5.00                                 4.50
# 2                          5.00                                 4.75
# 3                          4.34                                 3.98
# 4                          4.71                                 4.69
#
#    Clear learning objectives & goals  \
# 0                               4.74
# 1                               4.50
# 2                               5.00
# 3                               4.05
# 4                               4.72
#
#    Instructor provides feedback to students to improve  \
# 0                                               4.05
# 1                                               4.50
# 2                                               5.00
# 3                                               3.89
# 4                                               4.53
#
#    Demonstrate importance of subject matter  \
# 0                                      4.58
# 1                                      5.00
# 2                                      5.00
# 3                                      4.48
# 4                                      4.72
#
#    Explains subject matter of course  Show respect for all students  \
# 0                               4.63                           4.95
# 1                               4.50                           5.00
# 2                               4.88                           5.00
# 3                               4.02                           4.69
# 4                               4.72                           4.81
#
#    Overall teaching rate  Overall course rate
# 0                   4.47                 4.37
# 1                   4.50                 4.50
# 2                   5.00                 4.88
# 3                   3.98                 3.72
# 4                   4.67                 4.72

# %%
df_session_info = pd.merge(df_session_info, df_course_info, on=['course_num'])

# %%
df_session_info.head()
# Out:
#    course                                        session          start_time  \
# 0  05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 1  05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 2  05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 3  05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
# 4  05410A  classinsight-cmu_05410A_ghc_4301_201904221500 2019-04-22 15:00:00
#
#   start_hour classroom  completed  num_frames  max_frame  duration_in_mins  \
# 0      15:00  ghc_4301       True       23998      71991                79
# 1      15:00  ghc_4301       True       23998      71991                79
# 2      15:00  ghc_4301       True       23998      71991                79
# 3      15:00  ghc_4301       True       23998      71991                79
# 4      15:00  ghc_4301       True       23998      71991                79
#
#    course_num  S.No Semester Division Dept  \
# 0        5410     8      NaN      NaN  NaN
# 1        5410     8      NaN      NaN  NaN
# 2        5410     8      NaN      NaN  NaN
# 3        5410     8      NaN      NaN  NaN
# 4        5410     8      NaN      NaN  NaN
#
#                              course_name Course Level  Hrs Per Week  \
# 0  User-Centered Research and Evaluation          NaN           NaN
# 1  User-Centered Research and Evaluation          NaN           NaN
# 2  User-Centered Research and Evaluation          NaN           NaN
# 3  User-Centered Research and Evaluation          NaN           NaN
# 4  User-Centered Research and Evaluation          NaN           NaN
#
#   course_category                                        description  \
# 0          theory  This course provides an overview and introduct...
# 1          theory  This course provides an overview and introduct...
# 2          theory  This course provides an overview and introduct...
# 3          theory  This course provides an overview and introduct...
# 4          theory  This course provides an overview and introduct...
#
#    Interest in student learning  Clearly explain course requirements  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                                  NaN
# 4                           NaN                                  NaN
#
#    Clear learning objectives & goals  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    Instructor provides feedback to students to improve  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Demonstrate importance of subject matter  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Explains subject matter of course  Show respect for all students  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#    Overall teaching rate  Overall course rate
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN

# %%
df_session_info[df_session_info.course=='05748A']
# Out:
# Empty DataFrame
# Columns: [course, session, start_time, start_hour, classroom, completed, num_frames, max_frame, duration_in_mins, course_num, S.No, Semester, Division, Dept, course_name, Course Level, Hrs Per Week, course_category, description, Interest in student learning, Clearly explain course requirements, Clear learning objectives & goals, Instructor provides feedback to students to improve, Demonstrate importance of subject matter, Explains subject matter of course, Show respect for all students, Overall teaching rate, Overall course rate]
# Index: []

# %%
df_course_info = df_session_info.groupby(['course','Semester','Course Level','course_category','Division','start_hour']).agg({
    'completed':'count',
    'duration_in_mins':['min','mean','max'],
    'num_frames':['min','mean','max'],}).reset_index()
df_course_info.columns = ['course','Semester','Course Level','course_category','Division','start_hour','num_sessions','dur_min','dur_mean','dur_max','frame_count_min','frame_count_mean','frame_count_max']
df_course_info= df_course_info[df_course_info.dur_mean > 25]
df_course_info.sort_values(by='start_hour',ascending=False).reset_index(drop=True)

# %%
# 15 courses: 1.5 hours
# 18 courses: 1 hour
# 2 courses: half hour

# %% [markdown]
# # Cache single session tracking for id consistency

# %%
# sample_course = '17214B'
# sample_session = 'classinsight-cmu_17214B_ph_a21_201905011030-front'
# sample_session_dir = frame_file_data[sample_course][sample_session]['dir_location']
# sample_frame_ids = frame_file_data[sample_course][sample_session]['frame_ids']
# sample_session_dir

# %%
# session_tracking_ids = {}
# for frame_id in sample_frame_ids:
#     frame_data = pickle.load(open(f'{sample_session_dir}/{frame_id}.pb','rb'))
#     frame_tracking_ids = [xr['track_id'] for xr in frame_data[1]]
#     # print(frame_id, frame_tracking_ids)
#     session_tracking_ids[frame_id] = {int(xr):1 for xr in frame_tracking_ids}
# df_session_ids = pd.DataFrame.from_dict(session_tracking_ids)

# %%
# df_session_ids.head()

# %%
# np.unique(np.nansum(df_session_ids.values,axis=1) // 5, return_counts=True)

# %%
session_tracking_cache = '../cache/analysis_tracking/session_tracking_info'

# %%
unfinished_sessions = []
for course_idx, course in enumerate(frame_file_data):
    for session_idx, session_id in enumerate(frame_file_data[course]):
        session_tracking_cache_file = f"{session_tracking_cache}/{session_id}.pb"
        try:
            if not os.path.exists(session_tracking_cache_file):
                session_dir = frame_file_data[course][session_id]['dir_location']
                frame_ids = frame_file_data[course][session_id]['frame_ids']
                session_tracking_ids = {}
                for frame_id in frame_ids:
                    frame_data = pickle.load(open(f'{session_dir}/{frame_id}.pb','rb'))
                    frame_tracking_ids = [xr['track_id'] for xr in frame_data[1]]
                    # print(frame_id, frame_tracking_ids)
                    session_tracking_ids[frame_id] = {int(xr):1 for xr in frame_tracking_ids}
                df_session_ids = pd.DataFrame.from_dict(session_tracking_ids)
                pickle.dump(df_session_ids, open(session_tracking_cache_file,'wb'))
                print(f"Got tracking info for session: {course_idx}-{course}, session:{session_idx}-{session_id}")
            else:
                ...
                # print(f"FILE EXISTS: tracking info for session: {course_idx}-{course}, session:{session_idx}-{session_id}")
        except:
            print(f"ERROR: Unable to get session tracking for: {course_idx}-{course}, session:{session_idx}-{session_id}")
            unfinished_sessions.append((course, session_id))
            print(traceback.format_exc())

# %% [markdown]
# # Setup tracking id experiment by random selection of courses, sessions and snippets

# %%
df_session_info.head()

# %%
# randomly select 10 courses.
np.random.seed(43)
prefiltered_courses = df_session_info.course.drop_duplicates().sample(n=10)
print(f"Prefiltered courses:{prefiltered_courses}")

# select 5 sessions per course 
df_prefiltered_sessions = pd.DataFrame()
for course in prefiltered_courses.values:
    if df_session_info[df_session_info.course==course].shape[0]>5:
        df_prefiltered_sessions.append(df_session_info[df_session_info.course==course].sample(n=5))
df_prefiltered_sessions

# %%
df_prefiltered_sessions
